# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read file

# %%
flights_master = pd.read_csv(r"../data/flights_2019.csv")
flights_master.head()
# Out:
#    Unnamed: 0     fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0           0  2019-11-14                 AA       AA_CODESHARE          AA
# 1           1  2019-11-14                 AA       AA_CODESHARE          AA
# 2           2  2019-11-14                 AA       AA_CODESHARE          AA
# 3           3  2019-11-14                 AA       AA_CODESHARE          AA
# 4           4  2019-11-14                 AA       AA_CODESHARE          AA
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                4867                PT   N639AE               4867
# 1                4868                PT   N609DP               4868
# 2                4869                PT   N628AE               4869
# 3                4869                PT   N628AE               4869
# 4                4870                PT   N645AE               4870
#
#    origin_airport_id  ... distance carrier_delay  weather_delay nas_delay  \
# 0              14321  ...    364.0           NaN            NaN       NaN
# 1              12945  ...    281.0           NaN            NaN       NaN
# 2              12323  ...    413.0           NaN            NaN       NaN
# 3              14100  ...    413.0           NaN            NaN       NaN
# 4              13933  ...    241.0           NaN            NaN       NaN
#
#   security_delay  late_aircraft_delay  first_dep_time  total_add_gtime  \
# 0            NaN                  NaN             NaN              NaN
# 1            NaN                  NaN             NaN              NaN
# 2            NaN                  NaN             NaN              NaN
# 3            NaN                  NaN             NaN              NaN
# 4            NaN                  NaN             NaN              NaN
#
#    longest_add_gtime  no_name
# 0                NaN      NaN
# 1                NaN      NaN
# 2                NaN      NaN
# 3                NaN      NaN
# 4                NaN      NaN
#
# [5 rows x 43 columns]

# %%
flights_master.shape
# Out:
# (7545488, 43)

# %% [markdown]
# # Sample size reduction

# %%
flights = flights_master.copy()

# %%
flights.loc[:,["fl_date","crs_arr_time","crs_dep_time"]] = flights[["fl_date","crs_arr_time","crs_dep_time"]].astype('string')

arr_time = pd.to_datetime(flights["fl_date"]+" "+ flights["crs_arr_time"].str.zfill(4).replace({'2400':'0000'}))
dep_time = pd.to_datetime(flights["fl_date"]+" "+ flights["crs_dep_time"].str.zfill(4).replace({'2400':'0000'}))

flights["arr_date_time"] = arr_time
flights["dep_date_time"] = dep_time

flights['arr_month'] = flights['arr_date_time'].dt.month

# %%
def reduce_size(data):
    return data.sample(frac=0.1,random_state=1)
flights_sampled = flights.groupby(by=["op_unique_carrier","arr_month","dest_airport_id"]).apply(reduce_size).reset_index(drop=True)

# %%
flights_sampled.shape
# Out:
# (754138, 46)

# %%
flights_sampled = flights_sampled.drop(columns=["Unnamed: 0"])

# %%
flights_sampled.head()
# Out:
#       fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0  2019-01-02                 DL       DL_CODESHARE          DL
# 1  2019-01-25                 DL       DL_CODESHARE          DL
# 2  2019-01-03                 DL       DL_CODESHARE          DL
# 3  2019-01-17                 DL       DL_CODESHARE          DL
# 4  2019-01-29                 DL       DL_CODESHARE          DL
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                5303                9E   N606LR               5303
# 1                5443                9E   N905XJ               5443
# 2                5187                9E   N195PQ               5187
# 3                5443                9E   N310PQ               5443
# 4                5023                9E   N8928A               5023
#
#    origin_airport_id origin  ... nas_delay  security_delay  \
# 0              10397    ATL  ...       NaN             NaN
# 1              10397    ATL  ...       NaN             NaN
# 2              10397    ATL  ...       NaN             NaN
# 3              10397    ATL  ...       NaN             NaN
# 4              10397    ATL  ...       NaN             NaN
#
#   late_aircraft_delay first_dep_time total_add_gtime  longest_add_gtime  \
# 0                 NaN            NaN             NaN                NaN
# 1                 NaN            NaN             NaN                NaN
# 2                 NaN            NaN             NaN                NaN
# 3                 NaN            NaN             NaN                NaN
# 4                 NaN            NaN             NaN                NaN
#
#    no_name       arr_date_time       dep_date_time  arr_month
# 0      NaN 2019-01-02 17:14:00 2019-01-02 15:13:00          1
# 1      NaN 2019-01-25 17:18:00 2019-01-25 15:12:00          1
# 2      NaN 2019-01-03 23:35:00 2019-01-03 21:30:00          1
# 3      NaN 2019-01-17 17:18:00 2019-01-17 15:12:00          1
# 4      NaN 2019-01-29 14:45:00 2019-01-29 13:50:00          1
#
# [5 rows x 45 columns]

# %%
flights_sampled.to_csv(r"../data/sampled_data.csv",index=False)
